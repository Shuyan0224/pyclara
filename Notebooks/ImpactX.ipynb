# %%
import pyclara
import pandas
import matplotlib.pyplot as plt
import sdds
import numpy as np
# Out:
# initializing ocelot...
#
# RF-Track, version 2.5.5
#
# Copyright (C) 2016-2025 CERN, Geneva, Switzerland. All rights reserved.
#
# Author and contact:
#  Andrea Latina <andrea.latina@cern.ch>
#  BE-ABP Group
#  CERN
#  CH-1211 GENEVA 23
#  SWITZERLAND
#
# This software is distributed under a CERN proprietary software
# license in the hope that it will be useful, but WITHOUT ANY WARRANTY;
# not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# See the COPYRIGHT and LICENSE files at the top-level directory of
# the RF-Track download area: https://gitlab.cern.ch/rf-track
#
# RF-Track was compiled with GSL-2.8 and fftw-3.3.10
# [RF-Track] Could not check for updates.

# %%
ix = pyclara.Converters.elegant2impactx("../Run/FEBE.lte",
                                        start_element="CLA-FEA-SIM-DIP-04-END",
                                        end_element="CLA-FED-SIM-DUMP-01-START",
                                        elegant_twi="../Run/FEBE.twi")
# Out:
# Initializing AMReX (26.01)...
# OMP initialized with 12 OMP threads
# AMReX (26.01) initialized
#
# Grids Summary:
#   Level 0   1 grids  512 cells  100 % of domain
#
#  Diagnostics: 1
#  Space Charge effects: False
#  CSR effects: 0
#  ISR effects: 0
#  Spin tracking: 0
#
# ++++ Starting step=1 slice_step=0
#
# **** WARNINGS ******************************************************************
# * GLOBAL warning list  after  [ FIRST STEP ]
# *
# * No recorded warnings.
# ********************************************************************************
#
#
# ++++ Starting step=2 slice_step=0
#
# ++++ Starting step=3 slice_step=0
#
# ++++ Starting step=4 slice_step=0
#
# ++++ Starting step=5 slice_step=0
#
# ++++ Starting step=6 slice_step=0
#
# ++++ Starting step=7 slice_step=0
#
# ++++ Starting step=8 slice_step=0
#
# ++++ Starting step=9 slice_step=0
#
# ++++ Starting step=10 slice_step=0
#
# ++++ Starting step=11 slice_step=0
#
# ++++ Starting step=12 slice_step=0
#
# ++++ Starting step=13 slice_step=0
#
# ++++ Starting step=14 slice_step=0
#
# ++++ Starting step=15 slice_step=0
#
# ++++ Starting step=16 slice_step=0
#
# ++++ Starting step=17 slice_step=0
#
# ++++ Starting step=18 slice_step=0
#
# ++++ Starting step=19 slice_step=0
#
# ++++ Starting step=20 slice_step=0
#
# ++++ Starting step=21 slice_step=0
#
# ++++ Starting step=22 slice_step=0
#
# ++++ Starting step=23 slice_step=0
#
# ++++ Starting step=24 slice_step=0
#
# ++++ Starting step=25 slice_step=0
#
# ++++ Starting step=26 slice_step=0
#
# ++++ Starting step=27 slice_step=0
#
# ++++ Starting step=28 slice_step=0
#
# ++++ Starting step=29 slice_step=0
#
# ++++ Starting step=30 slice_step=0
#
# ++++ Starting step=31 slice_step=0
#
# ++++ Starting step=32 slice_step=0
#
# ++++ Starting step=33 slice_step=0
#
# ++++ Starting step=34 slice_step=0
#
# ++++ Starting step=35 slice_step=0
#
# ++++ Starting step=36 slice_step=0
#
# ++++ Starting step=37 slice_step=0
#
# ++++ Starting step=38 slice_step=0
#
# ++++ Starting step=39 slice_step=0
#
# ++++ Starting step=40 slice_step=0
#
# ++++ Starting step=41 slice_step=0
#
# ++++ Starting step=42 slice_step=0
#
# ++++ Starting step=43 slice_step=0
#
# ++++ Starting step=44 slice_step=0
#
# ++++ Starting step=45 slice_step=0
#
# ++++ Starting step=46 slice_step=0
#
# ++++ Starting step=47 slice_step=0
#
# ++++ Starting step=48 slice_step=0
#
# ++++ Starting step=49 slice_step=0
#
# ++++ Starting step=50 slice_step=0
#
# ++++ Starting step=51 slice_step=0
#
# ++++ Starting step=52 slice_step=0
#
# ++++ Starting step=53 slice_step=0
#
# ++++ Starting step=54 slice_step=0
#
# ++++ Starting step=55 slice_step=0
#
# ++++ Starting step=56 slice_step=0
#
# ++++ Starting step=57 slice_step=0
#
# ++++ Starting step=58 slice_step=0
#
# ++++ Starting step=59 slice_step=0
#
# ++++ Starting step=60 slice_step=0
#
# ++++ Starting step=61 slice_step=0
#
# ++++ Starting step=62 slice_step=0
#
# ++++ Starting step=63 slice_step=0
#
# ++++ Starting step=64 slice_step=0
#
# ++++ Starting step=65 slice_step=0
#
# ++++ Starting step=66 slice_step=0
#
# ++++ Starting step=67 slice_step=0
#
# ++++ Starting step=68 slice_step=0
#
# ++++ Starting step=69 slice_step=0
#
# ++++ Starting step=70 slice_step=0
#
# ++++ Starting step=71 slice_step=0
#
# ++++ Starting step=72 slice_step=0
#
# ++++ Starting step=73 slice_step=0
#
# ++++ Starting step=74 slice_step=0
#
# ++++ Starting step=75 slice_step=0
#
# ++++ Starting step=76 slice_step=0
#
# ++++ Starting step=77 slice_step=0
#
# ++++ Starting step=78 slice_step=0
#
# ++++ Starting step=79 slice_step=0
#
# ++++ Starting step=80 slice_step=0
#
# ++++ Starting step=81 slice_step=0
#
# ++++ Starting step=82 slice_step=0
#
# ++++ Starting step=83 slice_step=0
#
# ++++ Starting step=84 slice_step=0
#
# ++++ Starting step=85 slice_step=0
#
# ++++ Starting step=86 slice_step=0
#
# ++++ Starting step=87 slice_step=0
#
# ++++ Starting step=88 slice_step=0
#
# ++++ Starting step=89 slice_step=0
#
# ++++ Starting step=90 slice_step=0
#
# ++++ Starting step=91 slice_step=0
#
# ++++ Starting step=92 slice_step=0
#
# ++++ Starting step=93 slice_step=0
#
# ++++ Starting step=94 slice_step=0
#
# ++++ Starting step=95 slice_step=0
#
# ++++ Starting step=96 slice_step=0
#
# ++++ Starting step=97 slice_step=0
#
# ++++ Starting step=98 slice_step=0
#
# ++++ Starting step=99 slice_step=0
#
# ++++ Starting step=100 slice_step=0
#
# ++++ Starting step=101 slice_step=0
#
# ++++ Starting step=102 slice_step=0
#
# ++++ Starting step=103 slice_step=0
#
# ++++ Starting step=104 slice_step=0
#
# ++++ Starting step=105 slice_step=0
#
# ++++ Starting step=106 slice_step=0
#
# ++++ Starting step=107 slice_step=0
#
# ++++ Starting step=108 slice_step=0
#
# ++++ Starting step=109 slice_step=0
#
# ++++ Starting step=110 slice_step=0
#
# ++++ Starting step=111 slice_step=0
#
# ++++ Starting step=112 slice_step=0
#
# ++++ Starting step=113 slice_step=0
#
# ++++ Starting step=114 slice_step=0
#
# ++++ Starting step=115 slice_step=0
#
# ++++ Starting step=116 slice_step=0
#
# ++++ Starting step=117 slice_step=0
#
# ++++ Starting step=118 slice_step=0
#
# ++++ Starting step=119 slice_step=0
#
# ++++ Starting step=120 slice_step=0
#
# ++++ Starting step=121 slice_step=0
#
# ++++ Starting step=122 slice_step=0
#
# ++++ Starting step=123 slice_step=0
#
# ++++ Starting step=124 slice_step=0
#
# ++++ Starting step=125 slice_step=0
#
# ++++ Starting step=126 slice_step=0
#
# ++++ Starting step=127 slice_step=0
#
# ++++ Starting step=128 slice_step=0
#
# ++++ Starting step=129 slice_step=0
#
# ++++ Starting step=130 slice_step=0
#
# ++++ Starting step=131 slice_step=0
#
# ++++ Starting step=132 slice_step=0
#
# ++++ Starting step=133 slice_step=0
#
# ++++ Starting step=134 slice_step=0
#
# ++++ Starting step=135 slice_step=0
#
# ++++ Starting step=136 slice_step=0
#
# ++++ Starting step=137 slice_step=0
#
# ++++ Starting step=138 slice_step=0
#
# ++++ Starting step=139 slice_step=0
#
# ++++ Starting step=140 slice_step=0
#
# ++++ Starting step=141 slice_step=0
#
# ++++ Starting step=142 slice_step=0
#
# ++++ Starting step=143 slice_step=0
#
# ++++ Starting step=144 slice_step=0
#
# ++++ Starting step=145 slice_step=0
#
# ++++ Starting step=146 slice_step=0
#
# ++++ Starting step=147 slice_step=0
#
# ++++ Starting step=148 slice_step=0
#
# ++++ Starting step=149 slice_step=0
#
# ++++ Starting step=150 slice_step=0
#
# ++++ Starting step=151 slice_step=0
#
# ++++ Starting step=152 slice_step=0
#
# ++++ Starting step=153 slice_step=0
#
# ++++ Starting step=154 slice_step=0
#
# ++++ Starting step=155 slice_step=0
#
# ++++ Starting step=156 slice_step=0
#
# ++++ Starting step=157 slice_step=0
#
# ++++ Starting step=158 slice_step=0
#
# ++++ Starting step=159 slice_step=0
#
# ++++ Starting step=160 slice_step=0

# %%
df = pandas.read_csv("diags/reduced_beam_characteristics.0.0",
                     sep=r"\s+",
                     comment="#")

# %%
elegant_twi = sdds.load("../Run/FEBE.twi")

e_names = np.array(elegant_twi.getColumnValueList("ElementName"))
e_s = np.array(elegant_twi.getColumnValueList("s"))
e_betax = np.array(elegant_twi.getColumnValueList("betax"))
e_betay = np.array(elegant_twi.getColumnValueList("betay"))
e_etax = np.array(elegant_twi.getColumnValueList("etax"))
e_etay = np.array(elegant_twi.getColumnValueList("etay"))

e_idx0 = np.where(e_names == "CLA-FEA-SIM-DIP-04-END")[0] # TODO not sure about this offset 
e_idxN = np.where(e_names == "CLA-FED-SIM-DUMP-01-START")[0]

print(e_idx0, e_idxN, e_s[e_idx0], e_s[e_idxN])
plt.subplot(2,1,1)
plt.plot(e_s, e_betax, label="Elegant $\\beta_x$")
plt.plot(e_s, e_betay, label="Elegant $\\beta_y$")
plt.plot(df['s'] + e_s[e_idx0],df['beta_x'],"x", label="ImpactX $\\beta_x$")
plt.plot(df['s'] + e_s[e_idx0],df['beta_y'],"x", label="ImpactX $\\beta_y$")
plt.xlabel("s [m]")
plt.ylabel("$\\beta_{x,y}$ [m]");
plt.xlim(e_s[e_idx0], e_s[e_idxN]);
plt.legend()

plt.subplot(2,1,2)
plt.plot(e_s, e_etax, label="Elegant $\\eta_x$")
plt.plot(e_s, e_etay, label="Elegant $\\eta_y$")
plt.plot(df['s'] + e_s[e_idx0],df['dispersion_x'],"x", label="ImpactX $\\eta_x$")
plt.plot(df['s'] + e_s[e_idx0],df['dispersion_y'],"x", label="ImpactX $\\eta_y$")
plt.xlabel("s [m]")
plt.ylabel("$\\eta_{x,y}$ [m]");
plt.xlim(e_s[e_idx0], e_s[e_idxN]);
plt.legend(loc=2)

plt.savefig("ImpactX_ElegantComparision.jpg")
# Out:
# [383] [542] [60.449232] [83.569506]
